# %% [markdown]
# # Magma - Distinct Input, Shared Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from functools import partial
from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import kernax
kernax.config.parameter_transform = "softplus"  # Important for the stability of the optimisation
from kernax import WhiteNoiseKernel, SEKernel

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, Magma
# Out:
# INFO:2026-02-23 08:54:58,985:jax._src.xla_bridge:834: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaPipelines/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2026-02-23 08:54:58,985 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/MagmaPipelines/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
# Config
key = jax.random.PRNGKey(42)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %%
db = pd.read_csv(f"./datasets/K=1/{test_db_size}_distinct_input_shared_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /opt/miniconda3/envs/MagmaPipelines/lib/python3.12/site-packages/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /opt/miniconda3/envs/MagmaPipelines/lib/python3.12/site-packages/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
mean_kernel = 15. * SEKernel(length_scale=1.5)
task_kernel_train = 5. * SEKernel(length_scale=1.2) + WhiteNoiseKernel(noise=2.)
task_kernel_pred = deepcopy(task_kernel_train)

prior_mean = ZeroMean()

likelihood = BaseLikelihood()

# %%
model = Magma(likelihood=likelihood, prior_mean=prior_mean, mean_kernel=mean_kernel, task_kernel_train=task_kernel_train, task_kernel_pred=task_kernel_pred, shared_hp=True)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2026-02-23 08:55:00,587 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.50)
# 	Task kernel: 5.00 * SEKernel(length_scale=1.20) + WhiteNoiseKernel(noise=2.00)
# 2026-02-23 08:55:01,834 - INFO - Iteration    1	Llhs:    9211.7838,     442.2113	Conv. Ratio: inf
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.52)
# 	Task kernel: 5.98 * SEKernel(length_scale=1.24) + WhiteNoiseKernel(noise=0.26)
# 2026-02-23 08:55:02,579 - INFO - Iteration    2	Llhs:    6313.0856,     417.6315	Conv. Ratio: 0.30281
# 	Mean kernel: 15.02 * SEKernel(length_scale=1.72)
# 	Task kernel: 5.52 * SEKernel(length_scale=1.35) + WhiteNoiseKernel(noise=0.21)
# 2026-02-23 08:55:02,648 - INFO - Iteration    3	Llhs:    6292.9374,     415.1882	Conv. Ratio: 0.00336
# 	Mean kernel: 15.02 * SEKernel(length_scale=1.73)
# 	Task kernel: 5.32 * SEKernel(length_scale=1.33) + WhiteNoiseKernel(noise=0.20)
# 2026-02-23 08:55:02,682 - INFO - Iteration    4	Llhs:    6338.0378,     414.6346	Conv. Ratio: 0.00664
# 	Mean kernel: 15.02 * SEKernel(length_scale=1.73)
# 	Task kernel: 5.32 * SEKernel(length_scale=1.33) + WhiteNoiseKernel(noise=0.20)
# 2026-02-23 08:55:02,706 - INFO - Iteration    5	Llhs:    6296.1998,     414.7174	Conv. Ratio: 0.00618
# 	Mean kernel: 15.02 * SEKernel(length_scale=1.73)
# 	Task kernel: 5.31 * SEKernel(length_scale=1.32) + WhiteNoiseKernel(noise=0.20)
# 2026-02-23 08:55:02,729 - INFO - Iteration    6	Llhs:    6281.3415,     414.7987	Conv. Ratio: 0.00220
# 	Mean kernel: 15.02 * SEKernel(length_scale=1.73)
# 	Task kernel: 5.29 * SEKernel(length_scale=1.32) + WhiteNoiseKernel(noise=0.20)
# 2026-02-23 08:55:02,752 - INFO - Iteration    7	Llhs:    5639.6247,     414.8399	Conv. Ratio: 0.09583
# 	Mean kernel: 15.03 * SEKernel(length_scale=1.79)
# 	Task kernel: 5.29 * SEKernel(length_scale=1.32) + WhiteNoiseKernel(noise=0.20)
# 2026-02-23 08:55:02,786 - INFO - Iteration    8	Llhs:    5240.4685,     416.8986	Conv. Ratio: 0.06559
# 	Mean kernel: 15.03 * SEKernel(length_scale=1.82)
# 	Task kernel: 5.28 * SEKernel(length_scale=1.29) + WhiteNoiseKernel(noise=0.20)
# 2026-02-23 08:55:02,810 - INFO - Iteration    9	Llhs:    5202.6292,     418.6381	Conv. Ratio: 0.00638
# 	Mean kernel: 15.03 * SEKernel(length_scale=1.83)
# 	Task kernel: 5.29 * SEKernel(length_scale=1.27) + WhiteNoiseKernel(noise=0.20)
# 2026-02-23 08:55:02,843 - INFO - Iteration   10	Llhs:    5155.7542,     419.5797	Conv. Ratio: 0.00817
# 	Mean kernel: 15.03 * SEKernel(length_scale=1.83)
# 	Task kernel: 5.29 * SEKernel(length_scale=1.26) + WhiteNoiseKernel(noise=0.20)
# 2026-02-23 08:55:02,856 - INFO - Convergence reached after 11 iterations.	NLLs:    5158.6021,     420.0064
# 	Mean kernel: 15.03 * SEKernel(length_scale=1.83)
# 	Task kernel: 5.29 * SEKernel(length_scale=1.26) + WhiteNoiseKernel(noise=0.20)

# %%
model.generate_grid(grid_size)
model.grid_pred.shape
# Out:
# (250, 1)

# %%
mean_pred, mean_cov = model.predict()
mean_pred.shape, mean_cov.shape
# Out:
# ((4, 250), (4, 250, 250))

# %%
model.plot_mean_process()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()

# %%
model.plot_predictions(plot_as="samples", task_id=0, nb_samples=50)
plt.show()

# %% [markdown]
# ---
