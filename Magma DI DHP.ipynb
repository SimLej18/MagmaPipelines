# %% [markdown]
# # Magma - Distinct Input, Distinct Hyperparameters
#
# ---

# %% [markdown]
# ## Setup

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

from copy import deepcopy

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)

import kernax
kernax.config.parameter_transform = "softplus"  # Important for the stability of the optimisation
from kernax import WhiteNoiseKernel, SEKernel

import pandas as pd
from matplotlib import pyplot as plt

# %%
# Local
from MagmaClustPy.utils import split_db
from MagmaClustPy.means import ZeroMean
from MagmaClustPy.models import BaseLikelihood, Magma

# %%
# Config
key = jax.random.PRNGKey(2)
test_db_size = "small"
nb_cluster = 4
pred_id = 0
grid_size = 250  # number of points in the grid
grid_margin = 5  # grid goes from min(all_inputs) - margin to max(all_inputs) + margin
train_pred_ratio = 0.8  # ratio of train/pred tasks
pred_test_ratio = 0.7  # ratio of pred/test points in each pred task

# %% [markdown]
# ---

# %% [markdown]
# ## Model use

# %%
db = pd.read_csv(f"./datasets/K=1/{test_db_size}_distinct_input_distinct_hp.csv")
db_train, db_pred, db_test = split_db(db, train_ratio=train_pred_ratio, pred_ratio=pred_test_ratio)
# Out:
# /opt/miniconda3/envs/MagmaPipelines/lib/python3.12/site-packages/MagmaClustPy/utils.py:210: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_test = db_pred.groupby("Task_ID", group_keys=False).apply(
# /opt/miniconda3/envs/MagmaPipelines/lib/python3.12/site-packages/MagmaClustPy/utils.py:213: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   db_pred = db_pred.groupby("Task_ID", group_keys=False).apply(

# %%
mean_kernel = 15. * SEKernel(length_scale=1.5)
task_kernel_train = 5. * SEKernel(length_scale=1.2) + WhiteNoiseKernel(noise=2.)
task_kernel_pred = deepcopy(task_kernel_train)

prior_mean = ZeroMean()

likelihood = BaseLikelihood()

# %%
model = Magma(likelihood=likelihood, prior_mean=prior_mean, mean_kernel=mean_kernel, task_kernel_train=task_kernel_train, task_kernel_pred=task_kernel_pred, shared_hp=False)

# %%
model.load_train_data(db_train)
model.load_pred_data(db_pred)
model.load_test_data(db_test)

# %%
model.fit()
# Out:
# 2026-04-21 11:51:31,673 - INFO - Iteration    0	Llhs:          inf,          inf	Conv. Ratio: inf
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.50)
# 	Task kernel: [5.00 ± 0.00]₁₆ * SEKernel(length_scale=[1.20 ± 0.00]₁₆) + WhiteNoiseKernel(noise=[2.00 ± 0.00]₁₆)
# 2026-04-21 11:51:33,262 - INFO - Iteration    1	Llhs:   -2647.1024,     520.0454	Conv. Ratio: inf
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.64)
# 	Task kernel: [6.85 ± 2.68]₁₆ * SEKernel(length_scale=[1.34 ± 0.39]₁₆) + WhiteNoiseKernel(noise=[0.16 ± 0.24]₁₆)
# 2026-04-21 11:51:34,212 - INFO - Iteration    2	Llhs:   -2692.5892,     500.2517	Conv. Ratio: 0.03069
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.64)
# 	Task kernel: [6.70 ± 2.79]₁₆ * SEKernel(length_scale=[1.40 ± 0.38]₁₆) + WhiteNoiseKernel(noise=[0.14 ± 0.17]₁₆)
# 2026-04-21 11:51:34,270 - INFO - Iteration    3	Llhs:   -3128.0249,     494.5907	Conv. Ratio: 0.20120
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.69)
# 	Task kernel: [6.68 ± 2.81]₁₆ * SEKernel(length_scale=[1.41 ± 0.38]₁₆) + WhiteNoiseKernel(noise=[0.13 ± 0.15]₁₆)
# 2026-04-21 11:51:34,300 - INFO - Iteration    4	Llhs:   -3215.7456,     495.5685	Conv. Ratio: 0.03294
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.70)
# 	Task kernel: [6.70 ± 2.86]₁₆ * SEKernel(length_scale=[1.41 ± 0.38]₁₆) + WhiteNoiseKernel(noise=[0.13 ± 0.15]₁₆)
# 2026-04-21 11:51:34,329 - INFO - Iteration    5	Llhs:   -3239.5983,     496.8877	Conv. Ratio: 0.00828
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.70)
# 	Task kernel: [6.70 ± 2.87]₁₆ * SEKernel(length_scale=[1.41 ± 0.38]₁₆) + WhiteNoiseKernel(noise=[0.13 ± 0.15]₁₆)
# 2026-04-21 11:51:34,345 - INFO - Iteration    6	Llhs:   -4209.1769,     497.2839	Conv. Ratio: 0.35337
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.80)
# 	Task kernel: [6.70 ± 2.87]₁₆ * SEKernel(length_scale=[1.41 ± 0.38]₁₆) + WhiteNoiseKernel(noise=[0.13 ± 0.15]₁₆)
# 2026-04-21 11:51:34,369 - INFO - Iteration    7	Llhs:   -4463.8283,     506.5287	Conv. Ratio: 0.06611
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.83)
# 	Task kernel: [6.70 ± 2.86]₁₆ * SEKernel(length_scale=[1.38 ± 0.39]₁₆) + WhiteNoiseKernel(noise=[0.15 ± 0.19]₁₆)
# 2026-04-21 11:51:34,389 - INFO - Iteration    8	Llhs:   -4464.8309,     512.8696	Conv. Ratio: 0.00135
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.83)
# 	Task kernel: [6.72 ± 2.84]₁₆ * SEKernel(length_scale=[1.35 ± 0.41]₁₆) + WhiteNoiseKernel(noise=[0.15 ± 0.22]₁₆)
# 2026-04-21 11:51:34,411 - INFO - Iteration    9	Llhs:   -4462.7605,     515.8998	Conv. Ratio: 0.00129
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.83)
# 	Task kernel: [6.72 ± 2.84]₁₆ * SEKernel(length_scale=[1.34 ± 0.40]₁₆) + WhiteNoiseKernel(noise=[0.15 ± 0.24]₁₆)
# 2026-04-21 11:51:34,424 - INFO - Convergence reached after 10 iterations.	NLLs:   -4463.6017,     517.0627
# 	Mean kernel: 15.00 * SEKernel(length_scale=1.83)
# 	Task kernel: [6.72 ± 2.84]₁₆ * SEKernel(length_scale=[1.34 ± 0.40]₁₆) + WhiteNoiseKernel(noise=[0.15 ± 0.24]₁₆)

# %%
model.generate_grid(grid_size)
model.grid_pred.shape
# Out:
# (250, 1)

# %%
mean_pred, mean_cov = model.predict()
mean_pred.shape, mean_cov.shape
# Out:
# ((4, 250), (4, 250, 250))

# %%
model.plot_mean_process()
plt.show()

# %%
model.plot_predictions(plot_as="process", task_id=0)
plt.show()

# %%
model.plot_predictions(plot_as="samples", task_id=0, nb_samples=50)
plt.show()

# %% [markdown]
# ---
